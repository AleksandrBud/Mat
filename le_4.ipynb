# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Задание 3
#     1. Задание (в программе)
#         Нарисуйте график функции:
#         y(x) = k∙cos(x – a) + b
#         для некоторых (2-3 различных) значений параметров k, a, b

# %%
x = np.linspace(-4, 4, 200)
a = 1
b = 2
k = 3
y = [k*np.cos(i - a) + b for i in x]
a = -1
b = 4
k = 1
y2 =[k*np.cos(i - a) + b for i in x]
a = 5
b = -3
k = 1
y3 =[k*np.cos(i - a) + b for i in x]
plt.plot(x, y)
plt.plot(x, y2)
plt.plot(x, y3)
plt.xlabel("x")
plt.ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# 2. Задание
#     Докажите, что при ортогональном преобразовании сохраняется расстояние между точками.
#
#
#
#     Ответ: Нашел доказательство в интернете, на вид вроде простое, но я не понял его суть.

# %%
#  3. Задание (в программе)
#    1) Напишите код, который будет переводить полярные координаты в декартовы.
def pol2dec(r, g):
    x = r*np.cos(g)
    y = r*np.sin(g)
    return(x, y)
x, y = pol2dec(10, 45)
print(x)
print(y)
# Out:
# 5.253219888177298
# 8.509035245341185

# %%
# 2) Напишите код, который будет рисовать график окружности в полярных координатах.
x = np.linspace(-4, 4, 200)
y_p = [np.sqrt(4**2 - i**2) for i in x]
y_m = [np.sqrt(4**2 - i**2)*-1 for i in x]
plt.polar(x, y_p)
plt.polar(x, y_m)

# %%
# 3) Напишите код, который будет рисовать график отрезка прямой линии в полярных координатах.
x = np.linspace(-4, 4, 200)
y = 2*x + 10
plt.polar(x, y)

# %% [markdown]
# 4. Задание (в программе)
#     1) Решите систему уравнений:
#         y = x^2 – 1
#         exp(x) + x∙(1 – y) = 1

# %%
x = np. linspace(-20, 20, 2000)
plt.plot(x, (np.exp(x)+x-1)/x)
plt.plot(x, x**2 - 1)
plt.xlabel("x")
plt.ylabel("y")
plt.grid(True)
plt.xlim(-5, 7)
plt.ylim(-1,20)
plt.show()

# %%
from scipy.optimize import fsolve
def syst_func(a):
    x, y = a
    return(y - x**2 +1, (np.exp(x)+x-1)/x-y)
x1, y1 = fsolve(syst_func, (2,5))
print(x1, y1)
x1, y1 = fsolve(syst_func, (4,15))
print(x1, y1)
x1, y1 = fsolve(syst_func, (-2,1))
print(x1, y1)
x1, y1 = fsolve(syst_func, (0,-1))
print(x1, y1)
# Out:
# 2.618145573085375 5.854686241865328
# 4.200105841162491 16.640889076959716
# -1.581835352895886 1.5022030836712954
# 0.0 -1.0
# /home/aleksandr/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   after removing the cwd from sys.path.
# /home/aleksandr/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:162: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)

# %% [markdown]
#     2) Решите систему уравнений и неравенств:
#         y = x^2 – 1
#         exp(x) + x∙(1 – y) > 1

# %%
x = np. linspace(-20, 20, 2000)
plt.plot(x, np.exp(x)+x*(2-x**2)-1)
plt.xlabel("x")
plt.ylabel("y")
plt.grid(True)
plt.xlim(-5, 7)
plt.ylim(-7,10)
plt.show()

# %% [markdown]
# Ответ:
#     от -беск до -1,6;
#     от 0 до -2,6;
#     от 4,2 до беск.
