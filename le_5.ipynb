# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import itertools
import math

# %%
#1. Напишите код, моделирующий выпадение поля в рулетке (с учетом поля зеро).
for i in range(0,10):
    a = input()
    ver = 100/37
    x = np.random.uniform(0,100)
    if x < ver:
        print('0')
    elif x < ver*2:
        print('1')
    elif x < ver*3:
        print('2')
    elif x < ver*4:
        print('3')
    elif x < ver*5:
        print('4')
    elif x < ver*6:
        print('5')
    elif x < ver*7:
        print('6')
    elif x < ver*8:
        print('7')
    elif x < ver*9:
        print('8')
    elif x < ver*10:
        print('9')
    elif x < ver*11:
        print('10')
    elif x < ver*12:
        print('11')
    elif x < ver*13:
        print('12')
    elif x < ver*14:
        print('13')
    elif x < ver*15:
        print('14')
    elif x < ver*16:
        print('15')
    elif x < ver*17:
        print('16')
    elif x < ver*18:
        print('17')
    elif x < ver*19:
        print('18')
    elif x < ver*20:
        print('19')
    elif x < ver*21:
        print('20')
    elif x < ver*22:
        print('21')
    elif x < ver*23:
        print('22')
    elif x < ver*24:
        print('23')
    elif x < ver*25:
        print('24')
    elif x < ver*26:
        print('25')
    elif x < ver*27:
        print('26')
    elif x < ver*28:
        print('27')
    elif x < ver*29:
        print('28')
    elif x < ver*30:
        print('29')
    elif x < ver*31:
        print('30')
    elif x < ver*32:
        print('31')        
    elif x < ver*33:
        print('32')
    elif x < ver*34:
        print('33')
    elif x < ver*35:
        print('34')
    elif x < ver*36:
        print('35')
    elif x < ver*37:
        print('36')
    else:
        print('37')
# Out:
# 30
#
# 30
#
# 21
#
# 29
#
# 24
#
# 9
#
# 2
#
# 11
#
# 15
#
# 23

# %% [markdown]
# 2.
# 1)	Напишите код, проверяющий любую из теорем сложения или умножения вероятности на примере рулетки или подбрасывания монетки.

# %%
ver = 1/37
result = 0
print(ver)
for i in range(1,38):
    result = result + ver
print(result)
#Еденица не получается из-за погрешности округления
# Out:
# 0.02702702702702703
# 0.9999999999999991

# %% [markdown]
# 2)	Сгенерируйте десять выборок случайных чисел х0, …, х9.
# и постройте гистограмму распределения случайной суммы х0+х1+ …+ х9.

# %%
#a, b = 0, 0
#n = 10
#for i in range(0, n)
#    value = np.random.uniform(0, 100)
#    if value < 50:
#        a = a + 1
#    else
#        b = b + 1
sum_value = np.array([])
for i in range(0, 10):
    value = np.random.rand(10)
    sum_value = np.append(sum_value, np.sum(value))
num = 10
print(sum_value)
n, bins, path = plt.hist(sum_value, num)
# Out:
# [3.78756517 5.15067389 5.38629978 4.57031418 3.12938736 4.98301699
#  4.13090872 5.64970478 3.12385776 3.51493489]

# %% [markdown]
# 3.
# 1)	Дополните код Монте-Карло последовательности независимых испытаний расчетом соответствующих вероятностей (через биномиальное распределение)
# и сравните результаты.

# %%
k, n = 0, 10
a = np.random.randint(0, 2, n)
b = np.random.randint(0, 2, n)
c = np.random.randint(0, 2, n)
d = np.random.randint(0, 2, n)
x = a + b + c + d
for i in range(0, n):
    if x[i] == 2:
        k = k + 1
cnk = math.factorial(n)/(math.factorial(k)*(math.factorial(n-k)))
print(k, n, k/n, cnk/2**n)
# Out:
# 5 10 0.5 0.24609375

# %% [markdown]
# 2)	Повторите расчеты биномиальных коэффициентов и вероятностей k
# успехов в последовательности из n независимых испытаний, взяв другие значения n и k.

# %%
k, n = 0, 1000
a = np.random.randint(0, 2, n)
b = np.random.randint(0, 2, n)
c = np.random.randint(0, 2, n)
d = np.random.randint(0, 2, n)
x = a + b + c + d
for i in range(0, n):
    if x[i] == 3:
        k = k + 1
cnk = math.factorial(n)/(math.factorial(k)*(math.factorial(n-k)))
print(k, n, k/n, cnk/2**n)
# Out:
# 252 1000 0.252 3.997385606605008e-58

# %% [markdown]
# 4. Из урока по комбинаторике повторите расчеты,
# сгенерировав возможные варианты перестановок для других значений n и k

# %%
for p in itertools.permutations('01234567',5):
    print(''.join(str(x) for x in p))
# Out:
# 01234
# 01235
# 01236
# 01237
# 01243
# 01245
# 01246
# 01247
# 01253
# 01254
# 01256
# 01257
# 01263
# 01264
# 01265
# 01267
# 01273
# 01274
# 01275
# 01276
# 01324
# 01325
# 01326
# 01327
# 01342
# 01345
# 01346
# 01347
# 01352
# 01354
# 01356
# 01357
# 01362
# 01364
# 01365
# 01367
# 01372
# 01374
# 01375
# 01376
# 01423
# 01425
# 01426
# 01427
# 01432
# 01435
# 01436
# 01437
# 01452
# 01453
# 01456
# 01457
# 01462
# 01463
# 01465
# 01467
# 01472
# 01473
# 01475
# 01476
# 01523
# 01524
# 01526
# 01527
# 01532
# 01534
# 01536
# 01537
# 01542
# 01543
# 01546
# 01547
# 01562
# 01563
# 01564
# 01567
# 01572
# 01573
# 01574
# 01576
# 01623
# 01624
# 01625
# 01627
# 01632
# 01634
# 01635
# 01637
# 01642
# 01643
# 01645
# 01647
# 01652
# 01653
# 01654
# 01657
# 01672
# 01673
# 01674
# 01675
# 01723
# 01724
# 01725
# 01726
# 01732
# 01734
# 01735
# 01736
# 01742
# 01743
# 01745
# 01746
# 01752
# 01753
# 01754
# 01756
# 01762
# 01763
# 01764
# 01765
# 02134
# 02135
# 02136
# 02137
# 02143
# ...

# %%
5. Дополните код расчетом коэффициента корреляции x и y по формуле

# %%
n = 100
r = 0.7
x = np.random.rand(n)
y = r*x + (1 - r)*np.random.rand(n)
plt.plot(x, y, 'o')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
sr_x = np.sum(x)/n
sr_y = np.sum(y)/n
a = (np.sum(x)*np.sum(y) - n*np.sum(x*y))/(np.sum(x)*np.sum(x) - n*np.sum(x*y))
b = (np.sum(y) - a*np.sum(x))/n
x1 = x - sr_x
y1 = y - sr_y
R = np.sum(x1*y1)/np.sqrt(np.sum(x1**2)*np.sum(y1**2))
print(R)
A = np.vstack([x, np.ones(len(x))]).T
a1, b1 = np.linalg.lstsq(A, y)[0]
print(a, b)
print(a1, b1)
plt.plot([0, 1], [b, a + b])
plt.show()
# Out:
# 0.9353172589914591
# 1.0434724623657003 -0.027834844033702667
# 0.7417779899774801 0.13436176163045024
# D:\Program Files\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
